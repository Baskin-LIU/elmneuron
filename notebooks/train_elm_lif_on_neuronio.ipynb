# %%
# NOTE: reduced implementation might require slightly different parameters for same results

# %% [markdown]
# ## Notebook Config

# %%
# Imports
import gc
import os
import sys
import h5py
import random
from pathlib import Path
import matplotlib.pyplot as plt

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm import tqdm

# %%
# Relative Imports
package_path = Path(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))
sys.path.insert(0, str(package_path))

from src.expressive_leaky_memory_neuron_v2 import ELM
from src.LIF_surrogate import LIF
from src.neuronio.neuronio_data_utils import (
    NEURONIO_DATA_DIM, 
    NEURONIO_LABEL_DIM, 
    get_data_files_from_folder, 
    parse_sim_experiment_file,
    visualize_training_batch,
)
from src.neuronio.neuronio_data_loader_filtered import NeuronIO
from src.neuronio.neuronio_train_utils import NeuronioLoss
from src.neuronio.neuronio_eval_utils import (
    NeuronioEvaluator, 
    compute_test_predictions_multiple_sim_files, 
    filter_and_extract_core_results,
)

# %%
# General Config
general_config = dict()
general_config["seed"] = 0
general_config["device"] = 'cuda' if torch.cuda.is_available() else 'cpu'
general_config["short_training_run"] = True # TODO: change to full length run
general_config["verbose"] = general_config["short_training_run"]
torch_device = torch.device(general_config["device"])
print("Torch Device: ", torch_device)
# Out:
# Torch Device:  cuda

# %%
# Seeding & Determinism
os.environ['PYTHONHASHSEED'] = str(general_config["seed"])
random.seed(general_config["seed"])
np.random.seed(general_config["seed"])
torch.manual_seed(general_config["seed"])
torch.cuda.manual_seed(general_config["seed"])
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Data, Model, Training Config

# %%
# NOTE: this step requires you having downloaded the dataset

# Download Train Data: 
# https://www.kaggle.com/datasets/selfishgene/single-neurons-as-deep-nets-nmda-train-data
# Download Test Data: 
# https://www.kaggle.com/datasets/selfishgene/single-neurons-as-deep-nets-nmda-test-data # Data_test

# Location of downloaded folders
data_dir_path = Path("D:/NeuronIO").expanduser().resolve() # TODO: change to neuronio data path
train_data_dir_path = data_dir_path / "train"  # TODO: change to train subfolder
test_data_dir_path = data_dir_path / "test/Data_test"  # TODO: change to test subfolder

# %%
# Data Config

data_config = dict()
train_data_dirs = [
    str(train_data_dir_path / "full_ergodic_train_batch_2"),
    str(train_data_dir_path / "full_ergodic_train_batch_3"),
    str(train_data_dir_path / "full_ergodic_train_batch_4"),
    str(train_data_dir_path / "full_ergodic_train_batch_5"),
    str(train_data_dir_path / "full_ergodic_train_batch_6"),
    str(train_data_dir_path / "full_ergodic_train_batch_7"),
    str(train_data_dir_path / "full_ergodic_train_batch_8"),
    str(train_data_dir_path / "full_ergodic_train_batch_9"),
    str(train_data_dir_path / "full_ergodic_train_batch_10"),
]
valid_data_dirs = [str(train_data_dir_path / "full_ergodic_train_batch_1")]
test_data_dirs = [str(test_data_dir_path)]

data_config["train_data_dirs"] = train_data_dirs
data_config["valid_data_dirs"] = valid_data_dirs
data_config["test_data_dirs"] = test_data_dirs

data_config["data_dim"] = NEURONIO_DATA_DIM 
data_config["label_dim"] = NEURONIO_LABEL_DIM

# %%
# Model Config

model_config = dict()
model_config["num_input"] = data_config["data_dim"]
model_config["num_output"] = 1 #data_config["label_dim"]
model_config["num_memory"] = 10
model_config["memory_tau_max"] = 150.0
model_config["num_branch"] = 45
model_config["num_synapse_per_branch"] = 100
model_config["input_to_synapse_routing"] = "neuronio_routing"

# %%
# Training Config

train_config = dict()
train_config["num_epochs"] = 5 if general_config["short_training_run"] else 30
train_config["learning_rate"] = 5e-4
train_config["batch_size"] = 8 if general_config["short_training_run"] else 8
train_config["batches_per_epoch"] = 1000 if general_config["short_training_run"] else 5000
train_config["batches_per_epoch"] = int(8/train_config["batch_size"] * train_config["batches_per_epoch"])
train_config["file_load_fraction"] = 0.5 if general_config["short_training_run"] else 0.3
train_config["num_prefetch_batch"] = 2
train_config["num_workers"] = 4 # will make run nondeterministic
train_config["burn_in_time"] = 150
train_config["input_window_size"] = 500
train_config["rest_start"] = True
train_config["sec_len"] = 200
train_config["start_save_path"] = '../data_processed/NeuronIOstartpoint/'
train_config["ignore_time_from_start"] = 400

# %% [markdown]
# ## Data, Model, Training Setup

# %%
# Preparing Data Loaders

train_files = get_data_files_from_folder(data_config["train_data_dirs"])
valid_files = get_data_files_from_folder(data_config["valid_data_dirs"])
test_files = get_data_files_from_folder(data_config["test_data_dirs"])

train_data_loader = NeuronIO(
    file_paths=train_files,
    batches_per_epoch=train_config["batches_per_epoch"],
    batch_size=train_config["batch_size"],
    input_window_size=train_config["input_window_size"],
    num_workers=train_config["num_workers"],
    num_prefetch_batch=train_config["num_prefetch_batch"],
    file_load_fraction=train_config["file_load_fraction"],
    rest_start = train_config["rest_start"],
    sec_len = train_config["sec_len"],
    save_path = train_config["start_save_path"],
    seed=general_config["seed"],
    ignore_time_from_start = train_config["ignore_time_from_start"],
    device=torch_device,
)

train_evaluator = NeuronioEvaluator(
    test_file=train_files[0],
    burn_in_time=train_config["burn_in_time"],
    input_window_size=train_config["input_window_size"],
    device=torch_device,
)

valid_evaluator = NeuronioEvaluator(
    test_file=valid_files[0],
    burn_in_time=train_config["burn_in_time"],
    input_window_size=train_config["input_window_size"],
    device=torch_device,
)

# %%
# Visualize training data
X_viz, (y_spike_viz, y_soma_viz) = next(iter(train_data_loader))
visualize_training_batch(X_viz, y_spike_viz, y_soma_viz, num_viz=8)

# %%
# Initialize the ELM model
model = ELM(**model_config).to(torch_device)
spiking_model = LIF(v_rest=-0.3, v_reset=0.2, spike_duration=3, tau=-1).to(torch_device)

# Initialize the loss function, optimizer, and scheduler
MSEloss= nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=train_config["learning_rate"])
scheduler = CosineAnnealingLR(
    optimizer, 
    T_max=train_config["batches_per_epoch"] * train_config["num_epochs"]
)

# %%
# Visualize ELM model
print(model)
# Out:
# ELM(
#   (mlp): RecursiveScriptModule(
#     original_name=MLP
#     (network): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(original_name=Linear)
#       (1): RecursiveScriptModule(original_name=ReLU)
#       (2): RecursiveScriptModule(original_name=Linear)
#     )
#   )
#   (w_y): RecursiveScriptModule(original_name=Linear)
# )

# %%
#X_sample = ((torch.rand([8, 500, 1278]) > 0.8) * 1.).to(torch_device)
X_sample = X_viz
out = model(X_sample)
v, s = spiking_model(out)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1740

# %%
fig = plt.figure(figsize=(12,4))
index = 1
plt.plot(out[index][150:400].detach().cpu().numpy(), label = "ode")
plt.plot(v[index][150:400].detach().cpu().numpy(), label = 'v')
plt.plot(s[index][150:400].detach().cpu().numpy(), label = 's')
plt.plot(y_soma_viz[index][150:400].detach().cpu().numpy(), label = 'target_v')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(12,4))
index = 1
plt.plot(out[index][0:150].detach().cpu().numpy(), label = "ode")
plt.plot(v[index][0:150].detach().cpu().numpy(), label = 'v')
plt.plot(s[index][0:150].detach().cpu().numpy(), label = 's')
plt.plot(y_soma_viz[index][0:150].detach().cpu().numpy(), label = 'target_v')
plt.legend()
plt.show()

# %% [markdown]
# ## Training

# %%
# Initialize the best validation RMSE to a high value
best_valid_rmse = float('inf')
best_model_state_dict = model.state_dict().copy()

# Training loop
train_rmse_hist = []
train_auc_hist = []
valid_rmse_hist = []
valid_auc_hist = []
for epoch in range(train_config["num_epochs"]):
    # Training
    model.train()
    running_loss = 0.0
    pbar = tqdm(
        enumerate(train_data_loader, 0),
        total=train_config["batches_per_epoch"],
        disable=not general_config["verbose"],
    )
    for i, data in pbar:
        inputs, targets = data
        
        # Perform a single training step
        optimizer.zero_grad()
        outputs = model(inputs)
        v, s = spiking_model(outputs)
        loss = MSEloss(s, targets[0]) + MSEloss(v, targets[1])
        loss.backward()
        optimizer.step()
        scheduler.step()

        # Update running loss
        running_loss += loss.item()
        pbar.set_description(f"Epoch {epoch+1} Loss: {running_loss / (i+1):.5f}")
    
    # model.eval()
    # with torch.no_grad():
    #     # Evaluate on training data
    #     train_eval_metrics = train_evaluator.evaluate(model)
    #     train_rmse = train_eval_metrics["soma_RMSE"]
    #     train_auc = train_eval_metrics["AUC"]
    #     train_rmse_hist.append(train_rmse)
    #     train_auc_hist.append(train_auc)

    #     # Evaluate on validation data
    #     valid_eval_metrics = valid_evaluator.evaluate(model)
    #     valid_rmse = valid_eval_metrics["soma_RMSE"]
    #     valid_auc = valid_eval_metrics["AUC"]
    #     valid_rmse_hist.append(valid_rmse)
    #     valid_auc_hist.append(valid_auc)

    # # Copy model state dict if validation RMSE has improved
    # if valid_rmse < best_valid_rmse:
    #     best_valid_rmse = valid_rmse
    #     best_model_state_dict = model.state_dict().copy()

    # # Print statistics
    # print(
    #     f'Epoch: {epoch+1}, '
    #     f'Train Loss: {running_loss / train_config["batches_per_epoch"]:.5f}, '
    #     f'Train RMSE: {train_rmse:.5f}, Train AUC: {train_auc:.5f}, '
    #     f'Valid RMSE: {valid_rmse:.5f}, Valid AUC: {valid_auc:.5f}'
    # )

# Free up memory
del train_data_loader
gc.collect()

# Load the best model for evaluation
model.load_state_dict(best_model_state_dict)
model.eval();
# Out:
# Epoch 1 Loss: 138.14622: 100%|█████████████████████████████████████████████████| 1000/1000 [21:40<00:00,  1.30s/it]
# Epoch 2 Loss: 2.12001:  90%|██████████████████████████████████████████████▋     | 898/1000 [20:32<02:20,  1.37s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[16], line 27
#      26 loss = MSEloss(s, targets[0]) + MSEloss(v, targets[1])
# ---> 27 loss.backward()
#      28 optimizer.step()
#
# File C:\Anaconda3\envs\elm\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File C:\Anaconda3\envs\elm\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File C:\Anaconda3\envs\elm\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:2144, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2143     else:
# -> 2144         stb = self.InteractiveTB.structured_traceback(
#    2145             etype, value, tb, tb_offset=tb_offset
#    2146         )
#    2148 except Exception:
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1172 """Return a nice text document describing the traceback."""
# -> 1173 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                        tb_offset)
#    1176 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1130 try:
# -> 1131     mod = inspect.getmodule(cf.tb_frame)
#    1132     if mod is not None:
#
# File C:\Anaconda3\envs\elm\lib\inspect.py:738, in getmodule(object, _filename)
#     737 try:
# --> 738     file = getabsfile(object, _filename)
#     739 except (TypeError, FileNotFoundError):
#
# File C:\Anaconda3\envs\elm\lib\inspect.py:721, in getabsfile(object, _filename)
#     720 if _filename is None:
# --> 721     _filename = getsourcefile(object) or getfile(object)
#     722 return os.path.normcase(os.path.abspath(_filename))
#
# File C:\Anaconda3\envs\elm\lib\inspect.py:709, in getsourcefile(object)
#     708 # only return a non-existent filename if the module has a PEP 302 loader
# --> 709 if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     710     return filename
#
# File C:\Anaconda3\envs\elm\lib\inspect.py:747, in getmodule(object, _filename)
#     746 if ismodule(module) and hasattr(module, '__file__'):
# --> 747     f = module.__file__
#     748     if f == _filesbymodname.get(modname, None):
#     749         # Have already mapped this module, so skip it
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:3490, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3489     asy = compare(code)
# -> 3490 if await self.run_code(code, result, async_=asy):
#    3491     return True
#
#     [... skipping hidden 1 frame]
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:2165, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2164 except KeyboardInterrupt:
# -> 2165     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:2088, in InteractiveShell.get_exception_only(self, exc_tuple)
#    2087 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2088 msg = traceback.format_exception_only(etype, value)
#    2089 return ''.join(msg)
#
# File C:\Anaconda3\envs\elm\lib\traceback.py:140, in format_exception_only(etype, value)
#     125 """Format the exception part of a traceback.
#     126
#     127 The arguments are the exception type and value such as given by
#    (...)
#     138
#     139 """
# --> 140 return list(TracebackException(etype, value, None).format_exception_only())
#
# File C:\Anaconda3\envs\elm\lib\site-packages\exceptiongroup\_formatting.py:179, in PatchedTracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, _seen)
#     173 if (
#     174     e
#     175     and e.__context__ is not None
#     176     and need_context
#     177     and id(e.__context__) not in _seen
#     178 ):
# --> 179     context = PatchedTracebackException(
#     180         type(e.__context__),
#     181         e.__context__,
#     182         e.__context__.__traceback__,
#     183         limit=limit,
#     184         lookup_lines=lookup_lines,
#     185         capture_locals=capture_locals,
#     186         _seen=_seen,
#     187     )
#     188 else:
#
# File C:\Anaconda3\envs\elm\lib\site-packages\exceptiongroup\_formatting.py:96, in PatchedTracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, _seen)
#      94 _seen.add(id(exc_value))
# ---> 96 self.stack = traceback.StackSummary.extract(
#      97     traceback.walk_tb(exc_traceback),
#      98     limit=limit,
#      99     lookup_lines=lookup_lines,
#     100     capture_locals=capture_locals,
#     101 )
#     102 self.exc_type = exc_type
#
# File C:\Anaconda3\envs\elm\lib\traceback.py:366, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     365     for f in result:
# --> 366         f.line
#     367 return result
#
# File C:\Anaconda3\envs\elm\lib\traceback.py:288, in FrameSummary.line(self)
#     287 if self._line is None:
# --> 288     self._line = linecache.getline(self.filename, self.lineno).strip()
#     289 return self._line
#
# File C:\Anaconda3\envs\elm\lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      27 """Get a line for a Python source file from the cache.
#      28 Update the cache if it doesn't contain an entry for this file already."""
# ---> 30 lines = getlines(filename, module_globals)
#      31 if 1 <= lineno <= len(lines):
#
# File C:\Anaconda3\envs\elm\lib\linecache.py:46, in getlines(filename, module_globals)
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#
# File C:\Anaconda3\envs\elm\lib\linecache.py:136, in updatecache(filename, module_globals)
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#
# File C:\Anaconda3\envs\elm\lib\tokenize.py:392, in open(filename)
#     389 """Open a file in read only mode using the encoding detected by
#     390 detect_encoding().
#     391 """
# --> 392 buffer = _builtin_open(filename, 'rb')
#     393 try:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:2144, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2143     else:
# -> 2144         stb = self.InteractiveTB.structured_traceback(
#    2145             etype, value, tb, tb_offset=tb_offset
#    2146         )
#    2148 except Exception:
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1172 """Return a nice text document describing the traceback."""
# -> 1173 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                        tb_offset)
#    1176 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:1138, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1137             continue
# -> 1138     max_len = get_line_number_of_frame(cf.tb_frame)
#    1140 except OSError:
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:184, in get_line_number_of_frame(frame)
#     183     return first + len(lines)
# --> 184 return count_lines_in_py_file(filename)
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\ultratb.py:149, in count_lines_in_py_file(filename)
#     148 try:
# --> 149     with open(filename, "r") as file:
#     150         s = sum(1 for line in file)
#
# File C:\Anaconda3\envs\elm\lib\_bootlocale.py:11, in getpreferredencoding(do_setlocale)
#      10 if sys.platform.startswith("win"):
# ---> 11     def getpreferredencoding(do_setlocale=True):
#      12         if sys.flags.utf8_mode:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:3308, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3304 # Execute the user code
#    3305 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3308 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3309        interactivity=interactivity, compiler=compiler, result=result)
#    3311 self.last_execution_succeeded = not has_raised
#    3312 self.last_execution_result = result
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:3509, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3507     if result:
#    3508         result.error_before_exec = sys.exc_info()[1]
# -> 3509     self.showtraceback()
#    3510     return True
#    3512 return False
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:2165, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2162         self._showtraceback(etype, value, stb)
#    2164 except KeyboardInterrupt:
# -> 2165     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File C:\Anaconda3\envs\elm\lib\site-packages\IPython\core\interactiveshell.py:2088, in InteractiveShell.get_exception_only(self, exc_tuple)
#    2083 """
#    2084 Return as a string (ending with a newline) the exception that
#    2085 just occurred, without any traceback.
#    2086 """
#    2087 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2088 msg = traceback.format_exception_only(etype, value)
#    2089 return ''.join(msg)
#
# File C:\Anaconda3\envs\elm\lib\traceback.py:140, in format_exception_only(etype, value)
#     124 def format_exception_only(etype, value):
#     125     """Format the exception part of a traceback.
#     126
#     127     The arguments are the exception type and value such as given by
#    (...)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#
# File C:\Anaconda3\envs\elm\lib\site-packages\exceptiongroup\_formatting.py:179, in PatchedTracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, _seen)
#     172     need_context = True
#     173 if (
#     174     e
#     175     and e.__context__ is not None
#     176     and need_context
#     177     and id(e.__context__) not in _seen
#     178 ):
# --> 179     context = PatchedTracebackException(
#     180         type(e.__context__),
#     181         e.__context__,
#     182         e.__context__.__traceback__,
#     183         limit=limit,
#     184         lookup_lines=lookup_lines,
#     185         capture_locals=capture_locals,
#     186         _seen=_seen,
#     187     )
#     188 else:
#     189     context = None
#
# File C:\Anaconda3\envs\elm\lib\site-packages\exceptiongroup\_formatting.py:96, in PatchedTracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, _seen)
#      93     _seen = set()
#      94 _seen.add(id(exc_value))
# ---> 96 self.stack = traceback.StackSummary.extract(
#      97     traceback.walk_tb(exc_traceback),
#      98     limit=limit,
#      99     lookup_lines=lookup_lines,
#     100     capture_locals=capture_locals,
#     101 )
#     102 self.exc_type = exc_type
#     103 # Capture now to permit freeing resources: only complication is in the
#     104 # unofficial API _format_final_exc_line
#
# File C:\Anaconda3\envs\elm\lib\traceback.py:366, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     364 if lookup_lines:
#     365     for f in result:
# --> 366         f.line
#     367 return result
#
# File C:\Anaconda3\envs\elm\lib\traceback.py:288, in FrameSummary.line(self)
#     285 @property
#     286 def line(self):
#     287     if self._line is None:
# --> 288         self._line = linecache.getline(self.filename, self.lineno).strip()
#     289     return self._line
#
# File C:\Anaconda3\envs\elm\lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File C:\Anaconda3\envs\elm\lib\linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File C:\Anaconda3\envs\elm\lib\linecache.py:136, in updatecache(filename, module_globals)
#     134         return []
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#     138 except OSError:
#
# File C:\Anaconda3\envs\elm\lib\tokenize.py:392, in open(filename)
#     388 def open(filename):
#     389     """Open a file in read only mode using the encoding detected by
#     390     detect_encoding().
#     391     """
# --> 392     buffer = _builtin_open(filename, 'rb')
#     393     try:
#     394         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation

# %%
# Visualize predictions
with torch.no_grad():
    outputs = model.neuronio_eval_forward(X_viz)
    visualize_training_batch(X_viz, y_spike_viz, y_soma_viz, outputs[..., 0], outputs[..., 1], num_viz=8)

# %%
# Gather all evaluation metrics
with torch.no_grad():
    if not general_config["short_training_run"]:
        random.seed(general_config["seed"])
        select_train_files = random.choices(train_files, k=10)
        train_predictions = compute_test_predictions_multiple_sim_files(
            neuron=model,
            test_files=select_train_files,
            burn_in_time=train_config["burn_in_time"],
            input_window_size=train_config["input_window_size"],
            device=torch_device,
        )
        train_results = filter_and_extract_core_results(*train_predictions, verbose=False)

        valid_predictions = compute_test_predictions_multiple_sim_files(
            neuron=model,
            test_files=valid_files,
            burn_in_time=train_config["burn_in_time"],
            input_window_size=train_config["input_window_size"],
            device=torch_device,
        )
        valid_results = filter_and_extract_core_results(*valid_predictions, verbose=False)

    test_predictions = compute_test_predictions_multiple_sim_files(
        neuron=model,
        test_files=test_files,
        burn_in_time=train_config["burn_in_time"],
        input_window_size=train_config["input_window_size"],
        device=torch_device,
    )
    test_results = filter_and_extract_core_results(*test_predictions, verbose=False)

eval_results = dict()
if not general_config["short_training_run"]:
    eval_results["train_results"] = train_results
    eval_results["valid_results"] = valid_results
eval_results["test_results"] = test_results

# %%
# Show evaluation results
eval_results
# Out:
# {'test_results': {'TP @ 0.0025 FP': 0.0865561694290976,
#   'AUC @ 0.0025 FP': 0.04251381215469613,
#   'TP @ 0.0100 FP': 0.26918354818907303,
#   'AUC @ 0.0100 FP': 0.14777086218491403,
#   'AUC': 0.9338153124011094,
#   'soma_explained_variance_percent': 85.98870851908606,
#   'soma_RMSE': 1.1480491917564262,
#   'soma_MAE': 0.7998251122689763}}
